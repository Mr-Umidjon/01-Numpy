# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Umidjon/01-Numpy/blob/main/amaliy_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Maxammadsoliyev Umidbek 210-20

# %% [markdown]
# ### 1.	Google colab online kod tahrirchisida ro‘yhatdan o‘tish va yangi “amaliy_3” nomli .pynb fayl yaratish.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2.	heart.csv dataset faylini DataFrame ko‘rinishida chaqirib olish.

# %%
heart_data = pd.read_csv("/content/heart.csv")

# %%
heart_data.head(7)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# ...

# %%
heart_data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ### 3.	Ma’lumotlar to‘plamini train va test to‘plamlariga ajratish.

# %%
X = heart_data.drop("HeartDisease", axis=1)
Y = heart_data["HeartDisease"]

# %%
X.head(7)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
#
#   ExerciseAngina  Oldpeak ST_Slope
# 0              N      0.0       Up
# 1              N      1.0     Flat
# 2              N      0.0       Up
# 3              Y      1.5     Flat
# 4              N      0.0       Up
# 5              N      0.0       Up
# 6              N      0.0       Up

# %%
Y.head(7)
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# Name: HeartDisease, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
X_train.head(7)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 712   58   M           ASY        100          234          0     Normal
# 477   61   M           ASY        110            0          1     Normal
# 409   53   M           NAP        160            0          1        LVH
# 448   63   M           ASY        160          230          1     Normal
# 838   63   M           ASY        130          330          1        LVH
# 306   55   M           ASY        115            0          1     Normal
# 172   53   M           ATA        140          320          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 712    156              N      0.1       Up
# 477    108              Y      2.0     Down
# 409    122              Y      0.0     Flat
# 448    105              Y      1.0     Flat
# 838    132              Y      1.8       Up
# 306    155              N      0.1     Flat
# 172    162              N      0.0       Up

# %%
Y_train.head(7)
# Out:
# 712    1
# 477    1
# 409    1
# 448    1
# 838    1
# 306    1
# 172    0
# Name: HeartDisease, dtype: int64

# %%
X_test.head(7)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 668   63   F           ATA        140          195          0     Normal
# 30    53   M           NAP        145          518          0     Normal
# 377   65   M           ASY        160            0          1         ST
# 535   56   M           ASY        130            0          0        LVH
# 807   54   M           ATA        108          309          0     Normal
# 793   67   M           ASY        125          254          1     Normal
# 363   56   M           ASY        120            0          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 668    179              N      0.0       Up
# 30     130              N      0.0     Flat
# 377    122              N      1.2     Flat
# 535    122              Y      1.0     Flat
# 807    156              N      0.0       Up
# 793    163              N      0.2     Flat
# 363    148              N      0.0     Flat

# %%
Y_test.head(7)
# Out:
# 668    0
# 30     1
# 377    1
# 535    1
# 807    0
# 793    1
# 363    1
# Name: HeartDisease, dtype: int64
